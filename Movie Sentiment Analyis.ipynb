# %%
#https://www.kaggle.com/code/stpeteishii/movie-review-bert-lgbm

# %%
import sqlite3
import pandas as pd
import numpy as np
import os

import random
import matplotlib.pyplot as plt

# %%
# %pwd
# Out:
# 'c:\\Python-Projects\\NLP\\Movie Review Project'

# %%
movies = pd.read_csv(r'C:\\Python-Projects\\NLP\\Movie Review Project\\rotten_tomatoes_movies.csv')
movies
# Out:
#                         rotten_tomatoes_link  \
# 0                                  m/0814255
# 1                                  m/0878835
# 2                                       m/10
# 3                     m/1000013-12_angry_men
# 4      m/1000079-20000_leagues_under_the_sea
# ...                                      ...
# 17707                            m/zoot_suit
# 17708                             m/zootopia
# 17709                      m/zorba_the_greek
# 17710                                 m/zulu
# 17711                            m/zulu_dawn
#
#                                              movie_title  \
# 0      Percy Jackson & the Olympians: The Lightning T...
# 1                                            Please Give
# 2                                                     10
# 3                        12 Angry Men (Twelve Angry Men)
# 4                           20,000 Leagues Under The Sea
# ...                                                  ...
# ...

# %%
reviews = pd.read_csv(r'C:\\Python-Projects\\NLP\\Movie Review Project\\rotten_tomatoes_critic_reviews.csv')
reviews
# Out:
#         rotten_tomatoes_link        critic_name  top_critic  \
# 0                  m/0814255    Andrew L. Urban       False
# 1                  m/0814255      Louise Keller       False
# 2                  m/0814255                NaN       False
# 3                  m/0814255       Ben McEachen       False
# 4                  m/0814255        Ethan Alter        True
# ...                      ...                ...         ...
# 1130012          m/zulu_dawn      Chuck O'Leary       False
# 1130013          m/zulu_dawn          Ken Hanke       False
# 1130014          m/zulu_dawn    Dennis Schwartz       False
# 1130015          m/zulu_dawn  Christopher Lloyd       False
# 1130016          m/zulu_dawn     Brent McKnight       False
#
#                           publisher_name review_type review_score review_date  \
# 0                         Urban Cinefile       Fresh          NaN  2010-02-06
# 1                         Urban Cinefile       Fresh          NaN  2010-02-06
# ...

# %%
# new data frame with split value columns
new = reviews["review_score"].str.split(r'(/|\D)', expand=True)

# reviews["review_score"] = new[0]
# reviews["threshold"] = new[2]
# reviews
new
# Out:
#            0    1    2     3     4     5     6     7     8
# 0        NaN  NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1        NaN  NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2        NaN  NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3          3    .    5     /     5  None  None  None  None
# 4        NaN  NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...      ...  ...  ...   ...   ...   ...   ...   ...   ...
# 1130012    2    /    5  None  None  None  None  None  None
# 1130013    3    .    5     /     5  None  None  None  None
# 1130014         B          +        None  None  None  None
# 1130015    3    .    5     /     5  None  None  None  None
# 1130016         C       None  None  None  None  None  None
#
# [1130017 rows x 9 columns]

# %%
reviews.loc[reviews['review_score'] == 'A+', 'review_score'] = 5
reviews.loc[reviews['review_score'] == 'A', 'review_score'] = 5
reviews.loc[reviews['review_score'] == 'A-', 'review_score'] = 5
reviews.loc[reviews['review_score'] == 'A -', 'review_score'] = 5
reviews.loc[reviews['review_score'] == 'B+', 'review_score'] = 4
reviews.loc[reviews['review_score'] == 'B', 'review_score'] = 4
reviews.loc[reviews['review_score'] == 'B-', 'review_score'] = 4
reviews.loc[reviews['review_score'] == 'C+', 'review_score'] = 3
reviews.loc[reviews['review_score'] == 'C', 'review_score'] = 3
reviews.loc[reviews['review_score'] == 'C-', 'review_score'] = 3
reviews.loc[reviews['review_score'] == 'D+', 'review_score'] = 2
reviews.loc[reviews['review_score'] == 'D', 'review_score'] = 2
reviews.loc[reviews['review_score'] == 'D-', 'review_score'] = 2
reviews.loc[reviews['review_score'] == 'F+', 'review_score'] = 1
reviews.loc[reviews['review_score'] == 'F', 'review_score'] = 1
reviews.loc[reviews['review_score'] == 'F-', 'review_score'] = 1

# %%
reviews
# Out:
#         rotten_tomatoes_link        critic_name  top_critic  \
# 0                  m/0814255    Andrew L. Urban       False
# 1                  m/0814255      Louise Keller       False
# 2                  m/0814255                NaN       False
# 3                  m/0814255       Ben McEachen       False
# 4                  m/0814255        Ethan Alter        True
# ...                      ...                ...         ...
# 1130012          m/zulu_dawn      Chuck O'Leary       False
# 1130013          m/zulu_dawn          Ken Hanke       False
# 1130014          m/zulu_dawn    Dennis Schwartz       False
# 1130015          m/zulu_dawn  Christopher Lloyd       False
# 1130016          m/zulu_dawn     Brent McKnight       False
#
#                           publisher_name review_type review_score review_date  \
# 0                         Urban Cinefile       Fresh          NaN  2010-02-06
# 1                         Urban Cinefile       Fresh          NaN  2010-02-06
# ...

# %%
reviews.loc[(reviews['threshold'] == 'None') ]
# Out:
# Empty DataFrame
# Columns: [rotten_tomatoes_link, critic_name, top_critic, publisher_name, review_type, review_score, review_date, review_content, threshold]
# Index: []

# %%
for i in reviews["review_score"].unique():
    print(i)
# Out:
# nan
# 3
# 1
# 4
# 4
# 2
# 3
# 5
# 2
# 6
# 7
# 5
# 9
# 8
# 1
# 0

# %%
reviews["review_score"] = pd.to_numeric(reviews["review_score"])
reviews
# Out:
#         rotten_tomatoes_link        critic_name  top_critic  \
# 0                  m/0814255    Andrew L. Urban       False
# 1                  m/0814255      Louise Keller       False
# 2                  m/0814255                NaN       False
# 3                  m/0814255       Ben McEachen       False
# 4                  m/0814255        Ethan Alter        True
# ...                      ...                ...         ...
# 1130012          m/zulu_dawn      Chuck O'Leary       False
# 1130013          m/zulu_dawn          Ken Hanke       False
# 1130014          m/zulu_dawn    Dennis Schwartz       False
# 1130015          m/zulu_dawn  Christopher Lloyd       False
# 1130016          m/zulu_dawn     Brent McKnight       False
#
#                           publisher_name review_type  review_score  \
# 0                         Urban Cinefile       Fresh           NaN
# 1                         Urban Cinefile       Fresh           NaN
# ...
